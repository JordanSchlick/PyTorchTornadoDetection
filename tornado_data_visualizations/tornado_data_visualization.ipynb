# %%
import sys
import os
import numpy as np
import time
import datetime
import calendar
import math
import IPython
import importlib
from matplotlib import pyplot as plt
import matplotlib.animation
import matplotlib.image
import matplotlib
import tornado_data

#%config InlineBackend.figure_formats = ['svg']
#%config InlineBackend.figure_formats = ['jpeg']
# %config InlineBackend.figure_formats = ['retina']
#%config InlineBackend.figure_formats = ['png']
plt.rcParams['svg.fonttype'] = 'none'
plt.rcParams["figure.figsize"] = (7, 7)

importlib.reload(tornado_data)
tornado_data.load_data()

# %%
tornado_data.get_all_tornados()

# %%
all_tornados = tornado_data.get_all_tornados()

fig = plt.figure(figsize=(15,7))
ax = fig.add_subplot()
scat = ax.plot(all_tornados["BEGIN_LON"], all_tornados["BEGIN_LAT"], 'ro', markersize=5, markeredgewidth=0, alpha=0.05, label="Tornados")
plt.show()

# %%
fig = plt.figure(figsize=(16,8))
ax = fig.add_subplot(111)
plt.subplots_adjust(left=0, right=1, top=1, bottom=0)
ax.set_xlim(0,10)
ax.set_ylim(5,0)

us_map = matplotlib.image.imread('1859px-USA_location_map.svg.png')
plt.imshow(us_map, extent=[0,10,5,0])

min_lon = -125.5
max_lon = -66.5
min_lat = 24.2
max_lat = 49.8
ax.plot((all_tornados["BEGIN_LON"] - min_lon) / (max_lon - min_lon) * 10, (all_tornados["BEGIN_LAT"] - min_lat) / (max_lat - min_lat) * -5 + 5, 'ro', markersize=5, markeredgewidth=0, alpha=0.1, label="Tornados")

#plt.legend(loc='lower right', fontsize=12)

plt.axis('off')
plt.show()

# %%
fig = plt.figure(figsize=(16,8))
ax = fig.add_subplot(111)
plt.subplots_adjust(left=0, right=1, top=1, bottom=0)
ax.set_xlim(0,10)
ax.set_ylim(5,0)

us_map = matplotlib.image.imread('1859px-USA_location_map.svg.png')
plt.imshow(us_map, extent=[0,10,5,0])

min_lon = -125.5
max_lon = -66.5
min_lat = 24.2
max_lat = 49.8
# filtered_tornados = all_tornados[all_tornados["DEATHS_DIRECT"] > 0]
# filtered_tornados = all_tornados[all_tornados["TOR_F_SCALE"] == "EF4"]
filtered_tornados = all_tornados[all_tornados["DURATION"] > 60 * 5]
ax.plot((filtered_tornados["BEGIN_LON"] - min_lon) / (max_lon - min_lon) * 10, (filtered_tornados["BEGIN_LAT"] - min_lat) / (max_lat - min_lat) * -5 + 5, 'ro', markersize=10, markeredgewidth=0, alpha=0.2, label="One Tornado")

plt.legend(loc='lower right', fontsize=12)

plt.axis('off')
plt.show()

# %%
fig = plt.figure(figsize=(16,8))
ax = fig.add_subplot(111)
plt.subplots_adjust(left=0, right=1, top=1, bottom=0)
ax.set_xlim(0,10)
ax.set_ylim(5,0)

us_map = matplotlib.image.imread('1859px-USA_location_map.svg.png')
plt.imshow(us_map, extent=[0,10,5,0])

min_lon = -125.5
max_lon = -66.5
min_lat = 24.2
max_lat = 49.8
#filtered_tornados = all_tornados[all_tornados["DEATHS_DIRECT"] > 0]
filtered_tornados = all_tornados[all_tornados["TOR_F_SCALE"] == "EF4"]
ax.plot((filtered_tornados["BEGIN_LON"] - min_lon) / (max_lon - min_lon) * 10, (filtered_tornados["BEGIN_LAT"] - min_lat) / (max_lat - min_lat) * -5 + 5, 'ro', markersize=10, markeredgewidth=0, alpha=0.2, label="EF4 Tornados")
filtered_tornados = all_tornados[all_tornados["TOR_F_SCALE"] == "EF5"]
ax.plot((filtered_tornados["BEGIN_LON"] - min_lon) / (max_lon - min_lon) * 10, (filtered_tornados["BEGIN_LAT"] - min_lat) / (max_lat - min_lat) * -5 + 5, 'o', markersize=10, color="purple", markeredgewidth=0, alpha=0.4, label="EF5 Tornados")

plt.legend(loc='lower right', fontsize=12)

plt.axis('off')
plt.show()

# %%
scale=2
fig = plt.figure(figsize=(16*scale,8*scale))
ax = fig.add_subplot(111)
plt.subplots_adjust(left=0, right=1, top=1, bottom=0)
ax.set_xlim(0,10)
ax.set_ylim(5,0)

us_map = matplotlib.image.imread('1859px-USA_location_map.svg.png')
plt.imshow(us_map, extent=[0,10,5,0])

min_lon = -125.5
max_lon = -66.5
min_lat = 24.2
max_lat = 49.8

#scale *= 1.5

filtered_tornados = all_tornados[all_tornados["TOR_F_SCALE"] == "EF0"]
ax.plot((filtered_tornados["BEGIN_LON"] - min_lon) / (max_lon - min_lon) * 10, (filtered_tornados["BEGIN_LAT"] - min_lat) / (max_lat - min_lat) * -5 + 5, 'o', markersize=10*scale, color="blue", markeredgewidth=0, alpha=0.05, label="EF0 Tornados")
filtered_tornados = all_tornados[all_tornados["TOR_F_SCALE"] == "EF1"]
ax.plot((filtered_tornados["BEGIN_LON"] - min_lon) / (max_lon - min_lon) * 10, (filtered_tornados["BEGIN_LAT"] - min_lat) / (max_lat - min_lat) * -5 + 5, 'o', markersize=10*scale, color="green", markeredgewidth=0, alpha=0.1, label="EF1 Tornados")
filtered_tornados = all_tornados[all_tornados["TOR_F_SCALE"] == "EF2"]
ax.plot((filtered_tornados["BEGIN_LON"] - min_lon) / (max_lon - min_lon) * 10, (filtered_tornados["BEGIN_LAT"] - min_lat) / (max_lat - min_lat) * -5 + 5, 'o', markersize=10*scale, color="yellow", markeredgewidth=0, alpha=0.2, label="EF2 Tornados")
filtered_tornados = all_tornados[all_tornados["TOR_F_SCALE"] == "EF3"]
ax.plot((filtered_tornados["BEGIN_LON"] - min_lon) / (max_lon - min_lon) * 10, (filtered_tornados["BEGIN_LAT"] - min_lat) / (max_lat - min_lat) * -5 + 5, 'o', markersize=10*scale, color="orange", markeredgewidth=0, alpha=0.2, label="EF3 Tornados")
filtered_tornados = all_tornados[all_tornados["TOR_F_SCALE"] == "EF4"]
ax.plot((filtered_tornados["BEGIN_LON"] - min_lon) / (max_lon - min_lon) * 10, (filtered_tornados["BEGIN_LAT"] - min_lat) / (max_lat - min_lat) * -5 + 5, 'o', markersize=10*scale, color="red", markeredgewidth=0, alpha=0.3, label="EF4 Tornados")
filtered_tornados = all_tornados[all_tornados["TOR_F_SCALE"] == "EF5"]
ax.plot((filtered_tornados["BEGIN_LON"] - min_lon) / (max_lon - min_lon) * 10, (filtered_tornados["BEGIN_LAT"] - min_lat) / (max_lat - min_lat) * -5 + 5, 'o', markersize=10*scale, color="purple", markeredgewidth=0, alpha=0.5, label="EF5 Tornados")


plt.legend(loc='lower right', fontsize=12*scale)

plt.axis('off')
plt.show()

# %%
if 1:
	print("start animation")
	height = 6.5
	fig = plt.figure(figsize=(16,1.6*height))
	ax = fig.add_subplot(111)
	plt.subplots_adjust(left=0, right=1, top=1, bottom=0)
	ax.spines['top'].set_visible(False)
	ax.spines['right'].set_visible(False)
	ax.spines['bottom'].set_visible(False)
	ax.spines['left'].set_visible(False)
	
	ax.clear()
	ax.get_xaxis().set_visible(False)
	ax.get_yaxis().set_visible(False)
	ax.set_xlim(0,10)
	ax.set_ylim(height,0)
	us_map = matplotlib.image.imread('1859px-USA_location_map.svg.png')
	#us_map = matplotlib.image.imread('640px-USA_location_map.svg.png')
	imdata = ax.imshow(us_map, extent=[0,10,5,0])#, interpolation='nearest')
	#imdata.set_animated(True)
	
	
	
	
	# fig.canvas.draw()
	# fig.canvas.blit(fig.bbox)
	# bg = fig.canvas.copy_from_bbox(fig.bbox)
	
	#plot = ax.plot([], (all_tornados["BEGIN_LAT"] - min_lat) / (max_lat - min_lat) * -5 + 5, 'ro', markersize=5, markeredgewidth=0, alpha=0.1, label="Tornados")
	
	min_lon = -125.5
	max_lon = -66.5
	min_lat = 24.2
	max_lat = 49.8
	
	# epoch times from beginnning of 2007 to end of 2023
	start_year = 2007 # min of current data is 2017
	end_year = 2024 # max of current data is 2024
	start_time = datetime.datetime(start_year,1,1,0,0,0).timestamp()
	end_time = datetime.datetime(end_year,1,1,0,0,0).timestamp()
	frame_interval = 3600 * 24 * 30 # time per frame
	persistance_time = 3600 * 24 * 365 # how long into the past to display data each frame
	animation_frames = []
	for i in range(int((end_time - start_time) / frame_interval)):
		frame_time = start_time + i * frame_interval
		animation_frames.append(frame_time)
	
	# create time lines
	year_line_loc = 5.5
	if year_line_loc > 0:
		# all time
		line_loc = year_line_loc
		ax.hlines(line_loc, 1, 9, colors='black', linestyles='solid')
		for i in range(start_year, end_year + 1):
			xpos = (i - start_year) / float((end_year - start_year)) * 8 + 1
			#print(xpos)
			ax.text(xpos, line_loc-0.2, i, ha='left', va='center', fontsize=15)
			ax.vlines(xpos, line_loc - 0.1, line_loc + 0.1, colors='black', linestyles='solid')
	
	month_line_loc = 6
	if month_line_loc > 0:
		# months for one year
		line_loc = month_line_loc
		ax.hlines(line_loc, 1, 9, colors='black', linestyles='solid')
		for i in range(1,14):
			xpos = (i - 1) / 12.0 * 8 + 1
			if i <= 12:
				ax.text(xpos, line_loc-0.2, calendar.month_name[i], ha='left', va='center', fontsize=12)
			ax.vlines(xpos, line_loc - 0.1, line_loc + 0.1, colors='black', linestyles='solid')
	

	
	animation_bechmark_start = time.time()
	
	
	#plot, = plt.plot(0, 0, markersize=5, markeredgewidth=0, alpha=0.1, label="Tornados")
	
	def init():
		#print("init")
		
		return []
	
	artists = []
	
	def drawframe(frame):
		global artists
		elapsed_time = time.time() - animation_bechmark_start
		estimated_time_left = (elapsed_time) / (frame + 1) * (len(animation_frames) - frame)
		elapsed_time = round(elapsed_time / 60, 2)
		estimated_time_left = round(estimated_time_left / 60, 2)
		print("frame", frame + 1, "of", len(animation_frames), "eta", str(elapsed_time) + "-" + str(estimated_time_left), "min", "                     ", end='\r')
		time.sleep(0.05)
		animation_frame_time = animation_frames[frame]
		tornados = tornado_data.get_tornados(animation_frame_time - persistance_time, animation_frame_time)
		
		#axis_lines = ax.lines
		for item in artists:
			item.remove()
		
		# ax.clear()
		# ax.set_xlim(0,10)
		# ax.set_ylim(5,0)
		#fig.canvas.blit(fig.bbox)
		# fig.canvas.draw()
		# fig.canvas.restore_region(bg)
		# return []
		
		artists = []
		# artists.append(ax.hlines(5.5, 1, 9, colors='black', linestyles='solid'))
		if year_line_loc > 0:
			artists.extend(ax.plot([(animation_frame_time - start_time) / (end_time - start_time) * 8 + 1], [year_line_loc], 'o', markersize=10, color='black'))
		if month_line_loc > 0:
			artists.extend(ax.plot([((animation_frame_time - start_time) % (3600 * 24 * 365)) / (3600 * 24 * 365) * 8 + 1], [month_line_loc], 'o', markersize=10, color='black'))
		
		
		if len(tornados) > 0:
			plot = plt.plot((tornados["BEGIN_LON"] - min_lon) / (max_lon - min_lon) * 10, (tornados["BEGIN_LAT"] - min_lat) / (max_lat - min_lat) * -5 + 5, 'ro', markersize=10, markeredgewidth=0, alpha=0.1, label="Tornados")
			artists.extend(plot)
		return artists
	anim = matplotlib.animation.FuncAnimation(fig, drawframe, init_func=init, frames=len(animation_frames), interval=1000/20, blit=True)
	IPython.display.display(IPython.display.HTML(anim.to_html5_video()))
	plt.close()
